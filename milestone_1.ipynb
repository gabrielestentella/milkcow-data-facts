# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import numpy as np
import pandas as pd

# Load datasets
milkcow_facts = pd.read_csv("dataset/milkcow_facts.csv")
fluid_milk_sales = pd.read_csv("dataset/fluid_milk_sales.csv")
milk_products_facts = pd.read_csv("dataset/milk_products_facts.csv")
clean_cheese = pd.read_csv("dataset/clean_cheese.csv")
state_milk_production = pd.read_csv("dataset/state_milk_production.csv")

# Display basic info
datasets = {
    "milkcow_facts": milkcow_facts,
    "fluid_milk_sales": fluid_milk_sales,
    "milk_products_facts": milk_products_facts,
    "clean_cheese": clean_cheese,
    "state_milk_production": state_milk_production,
}

# %% [markdown]
# # Basic Info

# %%
for name, df in datasets.items():
    print(f"Dataset: {name}")
    display(df.head())
    print(df.info())
    print("\n" + "="*80 + "\n")

# Check for missing values
for name, df in datasets.items():
    print(f"Missing values in {name}:")
    print(df.isnull().sum())
    print("\n" + "="*80 + "\n")
# Out:
# Dataset: milkcow_facts
#      year  avg_milk_cow_number  milk_per_cow  milk_production_lbs  \
# 0  1980.0           10799000.0         11891         1.284060e+11
# 1  1981.0           10898000.0         12183         1.327700e+11
# 2  1982.0           11011000.0         12306         1.355050e+11
# 3  1983.0           11059000.0         12622         1.395880e+11
# 4  1984.0           10793000.0         12541         1.353510e+11
#
#    avg_price_milk  dairy_ration  milk_feed_price_ratio  \
# 0           0.130      0.048374               2.717149
# 1           0.138      0.050352               2.759031
# 2           0.136      0.044221               3.088127
# 3           0.136      0.052350               2.609620
# 4           0.135      0.053388               2.540000
#
#    milk_cow_cost_per_animal  milk_volume_to_buy_cow_in_lbs  alfalfa_hay_price  \
# 0                      1190                    9153.846154          72.000000
# 1                      1200                    8695.652174          70.900000
# 2                      1110                    8161.764706          72.733333
# 3                      1030                    7573.529412          78.700000
# 4                       895                    6629.629630          79.483333
#
#    slaughter_cow_price
# 0               0.4573
# 1               0.4193
# 2               0.3996
# 3               0.3935
# 4               0.3981
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   year                           35 non-null     float64
#  1   avg_milk_cow_number            35 non-null     float64
#  2   milk_per_cow                   35 non-null     int64
#  3   milk_production_lbs            35 non-null     float64
#  4   avg_price_milk                 35 non-null     float64
#  5   dairy_ration                   35 non-null     float64
#  6   milk_feed_price_ratio          35 non-null     float64
#  7   milk_cow_cost_per_animal       35 non-null     int64
#  8   milk_volume_to_buy_cow_in_lbs  35 non-null     float64
#  9   alfalfa_hay_price              35 non-null     float64
#  10  slaughter_cow_price            35 non-null     float64
# dtypes: float64(9), int64(2)
# memory usage: 3.1 KB
# None
#
# ================================================================================
#
# Dataset: fluid_milk_sales
#      year milk_type        pounds
# 0  1975.0     Whole  3.618800e+10
# 1  1976.0     Whole  3.524100e+10
# 2  1977.0     Whole  3.403600e+10
# 3  1978.0     Whole  3.323500e+10
# 4  1979.0     Whole  3.248000e+10
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 387 entries, 0 to 386
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   year       387 non-null    float64
#  1   milk_type  387 non-null    object
#  2   pounds     387 non-null    float64
# dtypes: float64(2), object(1)
# memory usage: 9.2+ KB
# None
#
# ================================================================================
#
# Dataset: milk_products_facts
#    year  fluid_milk  fluid_yogurt    butter  cheese_american  cheese_other  \
# 0  1975         247      1.967839  4.728193         8.147222      6.126409
# 1  1976         247      2.132685  4.313202         8.883106      6.627872
# 2  1977         244      2.338369  4.294180         9.213005      6.781846
# 3  1978         241      2.448503  4.354593         9.525359      7.309603
# 4  1979         238      2.443847  4.491231         9.597205      7.567657
#
#    cheese_cottage  evap_cnd_canned_whole_milk  evap_cnd_bulk_whole_milk  \
# 0        4.588537                    3.949932                  1.238596
# 1        4.632284                    3.791703                  1.100864
# 2        4.617711                    3.265569                  1.003802
# 3        4.600490                    3.148379                  0.900797
# 4        4.434472                    3.120396                  0.937452
#
#    evap_cnd_bulk_and_can_skim_milk  frozen_ice_cream_regular  \
# 0                         3.525306                 18.205053
# 1                         3.590506                 17.638453
# 2                         3.879376                 17.288945
# 3                         3.469461                 17.225330
# 4                         3.332083                 16.943414
#
#    frozen_ice_cream_reduced_fat  frozen_sherbet  frozen_other  dry_whole_milk  \
# 0                      6.502202        1.348780      1.816894             0.1
# 1                      6.169193        1.364460      1.678171             0.2
# 2                      6.574222        1.356254      1.627777             0.2
# 3                      6.550307        1.294786      1.511782             0.3
# 4                      6.197152        1.202817      1.413432             0.3
#
#    dry_nonfat_milk  dry_buttermilk  dry_whey
# 0         3.261769             0.2       2.2
# 1         3.504864             0.2       2.4
# 2         3.308311             0.3       2.4
# 3         3.101835             0.2       2.4
# 4         3.282367             0.2       2.7
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 18 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   year                             43 non-null     int64
#  1   fluid_milk                       43 non-null     int64
#  2   fluid_yogurt                     43 non-null     float64
#  3   butter                           43 non-null     float64
#  4   cheese_american                  43 non-null     float64
#  5   cheese_other                     43 non-null     float64
#  6   cheese_cottage                   43 non-null     float64
#  7   evap_cnd_canned_whole_milk       43 non-null     float64
#  8   evap_cnd_bulk_whole_milk         43 non-null     float64
#  9   evap_cnd_bulk_and_can_skim_milk  43 non-null     float64
#  10  frozen_ice_cream_regular         43 non-null     float64
#  11  frozen_ice_cream_reduced_fat     43 non-null     float64
#  12  frozen_sherbet                   43 non-null     float64
#  13  frozen_other                     43 non-null     float64
#  14  dry_whole_milk                   43 non-null     float64
#  15  dry_nonfat_milk                  43 non-null     float64
#  16  dry_buttermilk                   43 non-null     float64
#  17  dry_whey                         43 non-null     float64
# dtypes: float64(16), int64(2)
# memory usage: 6.2 KB
# None
#
# ================================================================================
#
# Dataset: clean_cheese
#    Year  Cheddar  American Other  Mozzarella  Italian other  Swiss  Brick  \
# 0  1970     5.79            1.20        1.19           0.87   0.88   0.10
# 1  1971     5.91            1.42        1.38           0.92   0.94   0.11
# 2  1972     6.01            1.67        1.57           1.02   1.06   0.10
# 3  1973     6.07            1.76        1.76           1.03   1.06   0.11
# 4  1974     6.31            2.16        1.86           1.09   1.18   0.11
#
#    Muenster  Cream and Neufchatel  Blue  Other Dairy Cheese  Processed Cheese  \
# 0      0.17                  0.61  0.15                0.41              3.32
# 1      0.19                  0.62  0.15                0.41              3.55
# 2      0.22                  0.63  0.17                0.56              3.51
# 3      0.21                  0.66  0.18                0.65              3.31
# 4      0.23                  0.70  0.16                0.61              3.42
#
#    Foods and spreads  Total American Chese  Total Italian Cheese  \
# 0               2.20                  7.00                  2.05
# 1               2.31                  7.32                  2.29
# 2               2.62                  7.68                  2.59
# 3               2.68                  7.83                  2.80
# 4               2.92                  8.47                  2.95
#
#    Total Natural Cheese  Total Processed Cheese Products
# 0                 11.37                             5.53
# 1                 12.03                             5.86
# 2                 13.01                             6.13
# 3                 13.49                             5.99
# 4                 14.41                             6.34
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 17 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Year                             48 non-null     int64
#  1   Cheddar                          48 non-null     float64
#  2   American Other                   48 non-null     float64
#  3   Mozzarella                       48 non-null     float64
#  4   Italian other                    48 non-null     float64
#  5   Swiss                            48 non-null     float64
#  6   Brick                            48 non-null     float64
#  7   Muenster                         48 non-null     float64
#  8   Cream and Neufchatel             48 non-null     float64
#  9   Blue                             36 non-null     float64
#  10  Other Dairy Cheese               48 non-null     float64
#  11  Processed Cheese                 48 non-null     float64
#  12  Foods and spreads                48 non-null     float64
#  13  Total American Chese             48 non-null     float64
#  14  Total Italian Cheese             48 non-null     float64
#  15  Total Natural Cheese             48 non-null     float64
#  16  Total Processed Cheese Products  48 non-null     float64
# dtypes: float64(16), int64(1)
# memory usage: 6.5 KB
# None
#
# ================================================================================
#
# Dataset: state_milk_production
#       region          state    year  milk_produced
# 0  Northeast          Maine  1970.0   6.190000e+08
# 1  Northeast  New Hampshire  1970.0   3.560000e+08
# 2  Northeast        Vermont  1970.0   1.970000e+09
# 3  Northeast  Massachusetts  1970.0   6.580000e+08
# 4  Northeast   Rhode Island  1970.0   7.500000e+07
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2400 entries, 0 to 2399
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   region         2400 non-null   object
#  1   state          2400 non-null   object
#  2   year           2400 non-null   float64
#  3   milk_produced  2400 non-null   float64
# dtypes: float64(2), object(2)
# memory usage: 75.1+ KB
# None
#
# ================================================================================
#
# Missing values in milkcow_facts:
# year                             0
# avg_milk_cow_number              0
# milk_per_cow                     0
# milk_production_lbs              0
# avg_price_milk                   0
# dairy_ration                     0
# milk_feed_price_ratio            0
# milk_cow_cost_per_animal         0
# milk_volume_to_buy_cow_in_lbs    0
# alfalfa_hay_price                0
# slaughter_cow_price              0
# dtype: int64
#
# ================================================================================
#
# Missing values in fluid_milk_sales:
# year         0
# milk_type    0
# pounds       0
# dtype: int64
#
# ================================================================================
#
# Missing values in milk_products_facts:
# year                               0
# fluid_milk                         0
# fluid_yogurt                       0
# butter                             0
# cheese_american                    0
# cheese_other                       0
# cheese_cottage                     0
# evap_cnd_canned_whole_milk         0
# evap_cnd_bulk_whole_milk           0
# evap_cnd_bulk_and_can_skim_milk    0
# frozen_ice_cream_regular           0
# frozen_ice_cream_reduced_fat       0
# frozen_sherbet                     0
# frozen_other                       0
# dry_whole_milk                     0
# dry_nonfat_milk                    0
# dry_buttermilk                     0
# dry_whey                           0
# dtype: int64
#
# ================================================================================
#
# Missing values in clean_cheese:
# Year                                0
# Cheddar                             0
# American Other                      0
# Mozzarella                          0
# Italian other                       0
# Swiss                               0
# Brick                               0
# Muenster                            0
# Cream and Neufchatel                0
# Blue                               12
# Other Dairy Cheese                  0
# Processed Cheese                    0
# Foods and spreads                   0
# Total American Chese                0
# Total Italian Cheese                0
# Total Natural Cheese                0
# Total Processed Cheese Products     0
# dtype: int64
#
# ================================================================================
#
# Missing values in state_milk_production:
# region           0
# state            0
# year             0
# milk_produced    0
# dtype: int64
#
# ================================================================================

# %% [markdown]
# # Basic Statistical Summary

# %%
for name, df in datasets.items():
    print(f"Summary statistics for {name}:")
    display(df.describe())
    print("\n" + "="*80 + "\n")
# Out:
# Summary statistics for milkcow_facts:
#               year  avg_milk_cow_number  milk_per_cow  milk_production_lbs  \
# count    35.000000         3.500000e+01     35.000000         3.500000e+01
# mean   1997.000000         9.695743e+06  16962.457143         1.625631e+11
# std      10.246951         6.967268e+05   3210.174197         2.205564e+10
# min    1980.000000         9.010000e+06  11891.000000         1.284060e+11
# 25%    1988.500000         9.171000e+06  14254.000000         1.444635e+11
# 50%    1997.000000         9.314000e+06  16871.000000         1.560910e+11
# 75%    2005.500000         1.013500e+07  19722.500000         1.793565e+11
# max    2014.000000         1.105900e+07  22259.000000         2.060540e+11
#
#        avg_price_milk  dairy_ration  milk_feed_price_ratio  \
# count       35.000000     35.000000              35.000000
# mean         0.146229      0.057844               2.696969
# std          0.028289      0.022268               0.504459
# min          0.121000      0.034454               1.520000
# 25%          0.127500      0.045502               2.540000
# 50%          0.136000      0.049138               2.700000
# 75%          0.153000      0.058863               3.030000
# max          0.240000      0.121500               3.640000
#
#        milk_cow_cost_per_animal  milk_volume_to_buy_cow_in_lbs  \
# count                 35.000000                      35.000000
# mean                1283.000000                    8848.270826
# std                  294.139323                    1740.672237
# min                  820.000000                    6560.000000
# 25%                 1100.000000                    7573.529412
# 50%                 1190.000000                    8625.954198
# 75%                 1425.000000                    9697.408214
# max                 1950.000000                   13410.852713
#
#        alfalfa_hay_price  slaughter_cow_price
# count          35.000000            35.000000
# mean          104.592524             0.487513
# std            39.128661             0.139614
# min            64.641667             0.330000
# 25%            79.220833             0.398850
# 50%            94.025000             0.450300
# 75%           109.200000             0.514700
# max           206.083333             1.020400
# ================================================================================
#
# Summary statistics for fluid_milk_sales:
#               year        pounds
# count   387.000000  3.870000e+02
# mean   1996.000000  1.196000e+10
# std      12.425738  1.666811e+10
# min    1975.000000  7.600000e+07
# 25%    1985.000000  8.365000e+08
# 50%    1996.000000  3.919500e+09
# 75%    2007.000000  1.747745e+10
# max    2017.000000  5.553129e+10
# ================================================================================
#
# Summary statistics for milk_products_facts:
#               year  fluid_milk  fluid_yogurt     butter  cheese_american  \
# count    43.000000   43.000000     43.000000  43.000000        43.000000
# mean   1996.000000  202.906977      7.163112   4.707052        11.954557
# std      12.556539   27.031564      4.338744   0.432596         1.503882
# min    1975.000000  149.000000      1.967839   4.187153         8.147222
# 25%    1985.500000  183.000000      3.782487   4.368419        11.281315
# 50%    1996.000000  205.000000      5.866495   4.543489        12.121953
# 75%    2006.500000  223.500000     11.309937   4.909321        12.952513
# max    2017.000000  247.000000     14.930392   5.694831        15.055745
#
#        cheese_other  cheese_cottage  evap_cnd_canned_whole_milk  \
# count     43.000000       43.000000                   43.000000
# mean      14.708003        3.128817                    2.035915
# std        4.815417        0.864649                    0.714998
# min        6.126409        2.070937                    0.940144
# 25%       10.676997        2.560796                    1.493747
# 50%       15.260577        2.654507                    1.838012
# 75%       18.959963        4.028232                    2.337994
# max       22.045776        4.632284                    3.949932
#
#        evap_cnd_bulk_whole_milk  evap_cnd_bulk_and_can_skim_milk  \
# count                 43.000000                        43.000000
# mean                   0.811673                         4.319382
# std                    0.290378                         0.816913
# min                    0.439140                         3.018296
# 25%                    0.577287                         3.642146
# 50%                    0.695640                         4.238769
# 75%                    1.057372                         5.167807
# max                    1.461874                         5.584490
#
#        frozen_ice_cream_regular  frozen_ice_cream_reduced_fat  frozen_sherbet  \
# count                 43.000000                     43.000000       43.000000
# mean                  15.626832                      6.396412        1.135682
# std                    1.645633                      0.429104        0.148392
# min                   12.468232                      5.672558        0.802910
# 25%                   14.691322                      6.079669        1.109774
# 50%                   15.710483                      6.326502        1.177925
# 75%                   17.056963                      6.612974        1.217540
# max                   18.205053                      7.551926        1.364460
#
#        frozen_other  dry_whole_milk  dry_nonfat_milk  dry_buttermilk  \
# count     43.000000       43.000000        43.000000       43.000000
# mean       3.127242        0.313706         3.021308        0.226870
# std        1.365373        0.140928         0.525746        0.053778
# min        1.348990        0.094963         2.120932        0.165213
# 25%        2.273999        0.196259         2.619406        0.197253
# 50%        2.909735        0.300000         3.049792        0.200000
# 75%        3.758539        0.400000         3.312888        0.245158
# max        6.539740        0.600000         4.284406        0.392408
#
#         dry_whey
# count  43.000000
# mean    3.045261
# std     0.657377
# min     1.890259
# 25%     2.400000
# 50%     3.022051
# 75%     3.650000
# max     4.087382
# ================================================================================
#
# Summary statistics for clean_cheese:
#           Year    Cheddar  American Other  Mozzarella  Italian other  \
# count    48.00  48.000000       48.000000   48.000000      48.000000
# mean   1993.50   8.889167        2.618333    6.860625       2.152917
# std      14.00   1.524678        0.654140    3.427934       0.730418
# min    1970.00   5.790000        1.200000    1.190000       0.870000
# 25%    1981.75   8.297500        2.220000    3.182500       1.522500
# 50%    1993.50   9.515000        2.585000    7.695000       2.185000
# 75%    2005.25   9.920000        2.965000    9.967500       2.752500
# max    2017.00  11.070000        3.990000   11.730000       3.490000
#
#            Swiss      Brick   Muenster  Cream and Neufchatel       Blue  \
# count  48.000000  48.000000  48.000000             48.000000  36.000000
# mean    1.155417   0.053958   0.340208              1.743958   0.198056
# std     0.112552   0.031130   0.089644              0.689350   0.060890
# min     0.880000   0.010000   0.170000              0.610000   0.150000
# 25%     1.067500   0.030000   0.277500              1.100000   0.160000
# 50%     1.170000   0.050000   0.335000              2.050000   0.170000
# 75%     1.240000   0.072500   0.402500              2.350000   0.182500
# max     1.350000   0.120000   0.530000              2.640000   0.320000
#
#        Other Dairy Cheese  Processed Cheese  Foods and spreads  \
# count           48.000000         48.000000          48.000000
# mean             1.018125          4.328542           3.163958
# std              0.364053          0.629072           0.442535
# min              0.410000          3.310000           1.910000
# 25%              0.750000          3.817500           2.987500
# 50%              0.965000          4.415000           3.220000
# 75%              1.295000          4.805000           3.440000
# max              1.590000          5.440000           3.980000
#
#        Total American Chese  Total Italian Cheese  Total Natural Cheese  \
# count             48.000000             48.000000             48.000000
# mean              11.507292              9.012292             25.345417
# std                1.950654              4.145494              7.365071
# min                7.000000              2.050000             11.370000
# 25%               10.810000              4.685000             19.470000
# 50%               11.830000              9.945000             26.290000
# 75%               12.837500             12.727500             31.782500
# max               15.060000             15.210000             37.230000
#
#        Total Processed Cheese Products
# count                        48.000000
# mean                          7.492500
# std                           0.869119
# min                           5.530000
# 25%                           6.897500
# 50%                           7.595000
# 75%                           8.195000
# max                           8.750000
# ================================================================================
#
# Summary statistics for state_milk_production:
#               year  milk_produced
# count  2400.000000   2.400000e+03
# mean   1993.500000   3.131642e+09
# std      13.856286   5.422561e+09
# min    1970.000000   3.000000e+06
# 25%    1981.750000   4.610000e+08
# 50%    1993.500000   1.347500e+09
# 75%    2005.250000   2.744250e+09
# max    2017.000000   4.233900e+10
# ================================================================================

# %% [markdown]
# # Milk Production Trends Over Time

# %%
top_milk_years = milkcow_facts.nlargest(5, "milk_production_lbs")[["year", "milk_production_lbs"]]
print("Top 5 years with highest milk production:")
display(top_milk_years)
# Out:
# Top 5 years with highest milk production:
#       year  milk_production_lbs
# 34  2014.0         2.060540e+11
# 33  2013.0         2.012310e+11
# 32  2012.0         2.006420e+11
# 31  2011.0         1.962550e+11
# 30  2010.0         1.928770e+11

# %%
milkcow_facts["year"] = pd.to_datetime(milkcow_facts["year"], format="%Y")
milkcow_facts.sort_values("year", inplace=True)

plt.figure(figsize=(10, 5))
plt.plot(milkcow_facts["year"], milkcow_facts["milk_production_lbs"], marker="o", linestyle="-", label="Total Milk Production")

plt.xlabel("Year")
plt.ylabel("Milk Production (lbs)")
plt.title("Total Milk Production Over Time")

def format_yaxis(value, _):
    return f"{value/1e9:.1f}B"

plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(format_yaxis))

plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # Milk Price vs. Dairy Ration Price Trend

# %%
plt.figure(figsize=(10, 5))
plt.plot(milkcow_facts["year"], milkcow_facts["avg_price_milk"], marker="o", label="Milk Price ($/lb)")
plt.plot(milkcow_facts["year"], milkcow_facts["dairy_ration"], marker="o", linestyle="dashed", label="Dairy Ration Price ($/lb)")
plt.xlabel("Year")
plt.ylabel("Price ($ per pound)")
plt.title("Milk Price vs. Dairy Ration Price Over Time")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # State-wise Milk Production

# %%
state_milk_production_grouped = state_milk_production.groupby("state")["milk_produced"].sum().sort_values(ascending=False)

plt.figure(figsize=(12, 6))
state_milk_production_grouped.head(10).plot(kind="bar", color="skyblue")
plt.xlabel("State")
plt.ylabel("Total Milk Produced (lbs)")
plt.title("Top 10 States in Milk Production")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Trends in Dairy Product Consumption (Cheese & Butter)

# %%
milk_products_facts["year"] = pd.to_datetime(milk_products_facts["year"], format="%Y")

plt.figure(figsize=(12, 6))
plt.plot(milk_products_facts["year"], milk_products_facts["cheese_american"], marker="o", label="American Cheese")
plt.plot(milk_products_facts["year"], milk_products_facts["cheese_other"], marker="o", linestyle="dashed", label="Other Cheese")
plt.plot(milk_products_facts["year"], milk_products_facts["butter"], marker="o", linestyle="dotted", label="Butter")
plt.xlabel("Year")
plt.ylabel("Consumption per Person (lbs)")
plt.title("Cheese & Butter Consumption Trends")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # Cheese Consumption Trends

# %%
clean_cheese["Year"] = pd.to_datetime(clean_cheese["Year"], format="%Y")

plt.figure(figsize=(12, 6))
plt.plot(clean_cheese["Year"], clean_cheese["Cheddar"], marker="o", label="Cheddar")
plt.plot(clean_cheese["Year"], clean_cheese["Mozzarella"], marker="o", linestyle="dashed", label="Mozzarella")
plt.plot(clean_cheese["Year"], clean_cheese["Swiss"], marker="o", linestyle="dotted", label="Swiss")
plt.xlabel("Year")
plt.ylabel("Consumption per Person (lbs)")
plt.title("Trends in Cheese Consumption")
plt.legend()
plt.grid()
plt.show()
